# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"yellow_tripdata_2015-01.csv")

# %%
import pandas as pd

def sample_uniform_by_day(
    df: pd.DataFrame,
    datetime_col: str = "tpep_pickup_datetime",
    n_per_day: int | None = None,
    frac_per_day: float | None = None,
    random_state: int = 42
) -> pd.DataFrame:
    """
    Samples uniformly at random within each day.
- Choose either `n_per_day` (fixed number of rows per day) or `frac_per_day` (fraction per day).
- If `n_per_day` > size of a given day, take all rows from that day.
    """
    if (n_per_day is None) == (frac_per_day is None):
        raise ValueError("Spécifie exactement l'un de `n_per_day` ou `frac_per_day`.")

    # Make sure the time column is set to datetime
    df = df.copy()
    df[datetime_col] = pd.to_datetime(df[datetime_col], errors="coerce")
    df = df.dropna(subset=[datetime_col])

    # Key ‘date’ (calendar day) from the time of pick-up
    df["_date"] = df[datetime_col].dt.date

    if n_per_day is not None:
        # Sampling with a fixed number per day (without replacement)
        out = (
            df.groupby("_date", group_keys=False)
              .apply(lambda g: g.sample(n=min(n_per_day, len(g)),
                                        replace=False,
                                        random_state=random_state))
        )
    else:
         # Sampling with one fraction per day
        out = (
            df.groupby("_date", group_keys=False)
              .apply(lambda g: g.sample(frac=frac_per_day,
                                        replace=False,
                                        random_state=random_state))
        )

    return out.drop(columns=["_date"])

# %% [markdown]
# # Fraction par jour (10% des données de chaque jour)

# %%
df_sample = sample_uniform_by_day(df, frac_per_day=0.010, random_state=42)
# Out:
# C:\Users\marwa\AppData\Local\Temp\ipykernel_32376\52674441.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.sample(frac=frac_per_day,

# %%
df_sample.shape
# Out:
# (127490, 19)

# %%
df_sample.dropna()
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 9690050          2  2015-01-01 16:07:13   2015-01-01 16:35:55
# 2813105          2  2015-01-01 15:59:47   2015-01-01 16:02:06
# 1965740          2  2015-01-01 04:05:37   2015-01-01 04:08:25
# 11762488         1  2015-01-01 10:10:53   2015-01-01 10:27:01
# 6320277          1  2015-01-01 03:30:14   2015-01-01 03:46:46
# ...            ...                  ...                   ...
# 455735           1  2015-01-31 02:20:39   2015-01-31 02:37:49
# 11885579         1  2015-01-31 15:55:06   2015-01-31 16:06:46
# 280131           2  2015-01-31 16:04:28   2015-01-31 16:25:14
# 2393737          1  2015-01-31 13:43:19   2015-01-31 13:57:11
# 793565           2  2015-01-31 13:23:36   2015-01-31 13:44:01
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 9690050                 1          18.26        -73.979401        40.760380
# 2813105                 1           0.66        -73.980637        40.730099
# 1965740                 5           0.33        -73.971985        40.749748
# 11762488                3           7.30        -74.010773        40.714050
# 6320277                 1           2.60        -73.982277        40.742973
# ...                   ...            ...               ...              ...
# 455735                  2           2.40        -74.002457        40.718697
# 11885579                1           1.50          0.000000         0.000000
# 280131                  1           4.84        -73.967323        40.766136
# 2393737                 1           1.60        -73.983215        40.730484
# 793565                  5           2.75        -73.997818        40.716797
#
#           RateCodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# 9690050            3                  N         -74.176826         40.694511
# 2813105            1                  N         -73.983124         40.722569
# 1965740            1                  N         -73.971886         40.746304
# 11762488           1                  N         -73.950073         40.779720
# 6320277            1                  N         -73.990211         40.712654
# ...              ...                ...                ...               ...
# 455735             1                  N         -73.974197         40.731674
# 11885579           1                  N           0.000000          0.000000
# 280131             1                  N         -73.949982         40.821941
# 2393737            1                  N         -73.999733         40.743397
# 793565             1                  N         -74.004448         40.742233
#
#           payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 9690050              2         66.0    0.0      0.0        0.00         16.35
# 2813105              2          4.0    0.0      0.5        0.00          0.00
# 1965740              2          4.0    0.5      0.5        0.00          0.00
# 11762488             1         22.5    0.0      0.5        5.00          0.00
# 6320277              2         12.5    0.5      0.5        0.00          0.00
# ...                ...          ...    ...      ...         ...           ...
# 455735               1         12.5    0.5      0.5        2.76          0.00
# 11885579             1          9.0    0.0      0.5        1.95          0.00
# 280131               2         18.5    0.0      0.5        0.00          0.00
# 2393737              1         10.0    0.0      0.5        2.00          0.00
# 793565               1         14.5    0.0      0.5        3.82          0.00
#
#           improvement_surcharge  total_amount
# 9690050                     0.3         82.65
# 2813105                     0.3          4.80
# 1965740                     0.3          5.30
# 11762488                    0.0         28.30
# 6320277                     0.0         13.80
# ...                         ...           ...
# 455735                      0.3         16.56
# 11885579                    0.3         11.75
# 280131                      0.3         19.30
# 2393737                     0.3         12.80
# 793565                      0.3         19.12
#
# [127490 rows x 19 columns]

# %%
df_sample.shape
# Out:
# (127490, 19)

# %% [markdown]
# Next step for me : fully understand the importance of each column and delete unnecessary columns.

# %%
df_sample = df_sample[df_sample["trip_distance"] > 0]

# %%
df_sample.shape
# Out:
# (126705, 19)

# %%
df_sample = df_sample.drop(columns=['store_and_fwd_flag'])

# %%
df_sample
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 9690050          2  2015-01-01 16:07:13   2015-01-01 16:35:55
# 2813105          2  2015-01-01 15:59:47   2015-01-01 16:02:06
# 1965740          2  2015-01-01 04:05:37   2015-01-01 04:08:25
# 11762488         1  2015-01-01 10:10:53   2015-01-01 10:27:01
# 6320277          1  2015-01-01 03:30:14   2015-01-01 03:46:46
# ...            ...                  ...                   ...
# 455735           1  2015-01-31 02:20:39   2015-01-31 02:37:49
# 11885579         1  2015-01-31 15:55:06   2015-01-31 16:06:46
# 280131           2  2015-01-31 16:04:28   2015-01-31 16:25:14
# 2393737          1  2015-01-31 13:43:19   2015-01-31 13:57:11
# 793565           2  2015-01-31 13:23:36   2015-01-31 13:44:01
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 9690050                 1          18.26        -73.979401        40.760380
# 2813105                 1           0.66        -73.980637        40.730099
# 1965740                 5           0.33        -73.971985        40.749748
# 11762488                3           7.30        -74.010773        40.714050
# 6320277                 1           2.60        -73.982277        40.742973
# ...                   ...            ...               ...              ...
# 455735                  2           2.40        -74.002457        40.718697
# 11885579                1           1.50          0.000000         0.000000
# 280131                  1           4.84        -73.967323        40.766136
# 2393737                 1           1.60        -73.983215        40.730484
# 793565                  5           2.75        -73.997818        40.716797
#
#           RateCodeID  dropoff_longitude  dropoff_latitude  payment_type  \
# 9690050            3         -74.176826         40.694511             2
# 2813105            1         -73.983124         40.722569             2
# 1965740            1         -73.971886         40.746304             2
# 11762488           1         -73.950073         40.779720             1
# 6320277            1         -73.990211         40.712654             2
# ...              ...                ...               ...           ...
# 455735             1         -73.974197         40.731674             1
# 11885579           1           0.000000          0.000000             1
# 280131             1         -73.949982         40.821941             2
# 2393737            1         -73.999733         40.743397             1
# 793565             1         -74.004448         40.742233             1
#
#           fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 9690050          66.0    0.0      0.0        0.00         16.35
# 2813105           4.0    0.0      0.5        0.00          0.00
# 1965740           4.0    0.5      0.5        0.00          0.00
# 11762488         22.5    0.0      0.5        5.00          0.00
# 6320277          12.5    0.5      0.5        0.00          0.00
# ...               ...    ...      ...         ...           ...
# 455735           12.5    0.5      0.5        2.76          0.00
# 11885579          9.0    0.0      0.5        1.95          0.00
# 280131           18.5    0.0      0.5        0.00          0.00
# 2393737          10.0    0.0      0.5        2.00          0.00
# 793565           14.5    0.0      0.5        3.82          0.00
#
#           improvement_surcharge  total_amount
# 9690050                     0.3         82.65
# 2813105                     0.3          4.80
# 1965740                     0.3          5.30
# 11762488                    0.0         28.30
# 6320277                     0.0         13.80
# ...                         ...           ...
# 455735                      0.3         16.56
# 11885579                    0.3         11.75
# 280131                      0.3         19.30
# 2393737                     0.3         12.80
# 793565                      0.3         19.12
#
# [126705 rows x 18 columns]

# %%
df_sample = df_sample.drop(columns=['passenger_count'])

# %%
df_sample = df_sample.drop(columns=['payment_type'])

# %%
df_sample = df_sample.drop(columns=['mta_tax'])

# %%
df_sample = df_sample.drop(columns=['improvement_surcharge'])
